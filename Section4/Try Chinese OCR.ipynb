# %% [markdown]
# <a href="https://colab.research.google.com/github/Gyeong-Hyeon/AI_Project/blob/main/Section4/Try%20Chinese%20OCR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #이미지에서 중국어 검출 모델 만들기..가 아니라 불러오기

# %%
# !pip install python-bidi

# %%
# !pip install easyocr
# Out:
# ...
#      |████████████████████████████████| 63.2MB 69kB/s
# ...

# %%
# !npx degit JaidedAI/EasyOCR/examples -f
# Out:
# npx: installed 1 in 2.664s
# > destination directory is not empty. Using --force, continuing
# > cloned JaidedAI/EasyOCR#HEAD

# %%
# !ls -l
# Out:
# total 3508
# -rw-r--r-- 1 root root   59898 Apr 21 20:51 chinese.jpg
# -rw-r--r-- 1 root root   97910 Apr 21 20:51 easyocr_framework.jpeg
# -rw-r--r-- 1 root root 1740957 Apr 21 20:51 english.png
# -rw-r--r-- 1 root root  487995 Apr 21 20:51 example2.png
# -rw-r--r-- 1 root root  127454 Apr 21 20:51 example3.png
# -rw-r--r-- 1 root root  488641 Apr 21 20:51 example.png
# -rw-r--r-- 1 root root  168376 Apr 21 20:51 french.jpg
# -rw-r--r-- 1 root root   42159 Apr 21 20:51 japanese.jpg
# -rw-r--r-- 1 root root  225531 Apr 21 20:51 korean.png
# drwxr-xr-x 1 root root    4096 Apr 21 13:39 sample_data
# -rw-r--r-- 1 root root   82229 Apr 21 20:51 thai.jpg
# -rw-r--r-- 1 root root   34706 Apr 21 20:51 width_ths.png

# %%
import easyocr
reader = easyocr.Reader(['en','ch_sim'])
# Out:
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-a8784f67-5adb-4dac-8b55-ceab3032fa5f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a8784f67-5adb-4dac-8b55-ceab3032fa5f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving menu.jfif to menu.jfif

# %%
import PIL
from PIL import ImageDraw
im = PIL.Image.open('./menu.jfif')
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=706x512 at 0x7F428404F450>

# %%
bounds = reader.readtext('./menu.jfif')
texts = []
for bound in bounds:
  texts.append(bound[1])

# %% [markdown]
# ##2. 불러온 텍스트를 받아서 번역하기

# %%
# Draw bounding boxes
def draw_boxes(image, bounds, color='yellow', width=2):
    draw = ImageDraw.Draw(image)
    for bound in bounds:
        p0, p1, p2, p3 = bound[0]
        draw.line([*p0, *p1, *p2, *p3, *p0], fill=color, width=width)
    return image

draw_boxes(im, bounds)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=683x512 at 0x7F4283BE3A10>
